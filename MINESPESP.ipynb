# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Solo versiones +1.17
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - Para versiones antiguas, ya esta disponible a exepcion de forge, seguir los pasos para usar un forge antiguo



version = '1.12.2' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - oldforge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO] Solo para versiones antiguas -1.17
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit) 1.20.1 29/09/24 ultima version disponible
# - catserver (Versión de Minecraft que combina Forge y Bukkit) 1.18.2 29/09/24 ultima version disponible
# - purpur (Versión de Minecraft que combina paper y Bukkit)

# Para usar paper primero tienes que instalar el vanilla
# Para usar mohist primero tienes que instalar el forge
# Para usar catserver primero tienes que instalar el forge
# Para usar purpur primero tienes que instalar el fabric

server_type = 'oldforge'

#Importa librerias necesarias para el funcionamiento del script 

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor 

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

elif server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

elif server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

elif server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version

elif server_type == 'fabric':
    serverURL = 'https://serverjars.com/api/fetchJar/modded/fabric/' + version

elif server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version
    
elif server_type == 'catserver':
    serverURL = "https://serverjars.com/api/fetchJar/modded/catserver/" + version

elif server_type == 'purpur':
    serverURL = "https://serverjars.com/api/fetchJar/servers/purpur/" + version

# Lista de nombres de los archivos

jar_name = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar", 
            'catserver': "catserver.jar", 'purpur': "purpur.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-server-launch.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

if server_type == 'vanilla':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar vanilla.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Error 404! La versión que has elegido probablemente no funciona.
# Completado!

# %%
#Tienes que poner el spawn proteccion en 0 para que puedas jugar de manera normal(esto dentro de Server.properties)
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading

import subprocess


#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)

# Instalar OpenJDK

version = colabconfig["server_version"]

# Ejecuta un comando en la terminal

def installjava17(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 17 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 17")

def installjava11(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 11 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 11")

def installjava8(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK 8 instalado correctamente")
    else:
        print("Fallo al instalar OpenJDK 8")
        
def purgejava(comando):
    proceso = subprocess.run(comando, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

    # Comprueba si el comando se ejecutó con éxito
    if proceso.returncode == 0:
        print("OpenJDK purgado correctamente")
    else:
        print("Fallo al purgar OpenJDK")

# Instala OpenJDK 17 si la versión de Minecraft es 1.17 o superior
# Si la versión es inferior, instala OpenJDK 8

if version < "1.12":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 8
    installjava8('sudo apt-get install openjdk-8-jre-headless -y')

elif version >= "1.12" and version < "1.17":
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 11
    installjava11('sudo apt-get install openjdk-11-jre-headless -y')

else:
    # Purga versiones anteriores de OpenJDK
    purgejava('sudo apt-get purge openjdk* -y')
    # Instala OpenJDK 17
    installjava17('sudo apt-get install openjdk-17-jre-headless -y')

# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

#Lista de posibles archivos .jar

jar_list = {'paper': 'paper.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar", 'catserver': "catserver.jar", 'purpur': "purpur.jar"}

jar_name = jar_list[colabconfig["server_type"]]

# Argumentos de java.

if colabconfig["server_type"] == "forge":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok  #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2de4oOD5pXkGwTByJ3pWAZlXUai_2uPiQeD8QGmihFvz6onDV" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'sa' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))


elif tunnel_service == "playit":

    subprocess.run(["curl", "-SsL", "https://playit-cloud.github.io/ppa/key.gpg"], check=True)
    subprocess.run(["sudo", "apt-key", "add", "key.gpg"], check=True)

    # Añadiendo el repositorio de Playit.gg
    subprocess.run(["sudo", "curl", "-SsL", "-o", "/etc/apt/sources.list.d/playit-cloud.list", "https://playit-cloud.github.io/ppa/playit-cloud.list"], check=True)

    # Actualizando la lista de paquetes
    subprocess.run(["sudo", "apt", "update"], check=True)

    # Instalando Playit.gg
    result = subprocess.run(["sudo", "apt", "install", "playit"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)

    # Comprueba si la instalación fue exitosa
    if result.returncode == 0:
        print("Playit.gg installed")
    else:
        print("Failed to install Playit.gg")

    # Iniciando el servidor con Playit.gg
    print('Starting server...')
    subprocess.run(["playit", "&", "java", "$memory_allocation", "$server_flags", "-jar", "$jar_name", "nogui"], check=True)

    # Obteniendo la IP del servidor
    result = subprocess.run(["playit", "status"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print("Tu ip es: " + result.stdout.decode())

#Obtiene la lista de usuarios de JSONPlaceholder
#Para mantener el servidor activo
def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

#Obtener el archivo de configuracion
stype = colabconfig["server_type"]
version = colabconfig["server_version"]

#Imprimir el tipo de servidor y la version
print("Estas jugando a minecraft: " + stype + " en su version: "+ version)

#Si el servidor es de tipo Forge antiguo no va a funcionar
if colabconfig["server_type"] == "forge" and colabconfig["server_version"] < "1.17.1":
    print("La version de Forge no es compatible con este script. Por favor, usa una version de Forge 1.17.1 o superior.")


#Si el servidor es de tipo Forge encontrara los archivos necesarios para ejecutar el servidor

if colabconfig["server_type"] == "forge":

    # Obtiene la versión de Forge
    
    forgefiles = f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/"
    
    forgepreversion = os.listdir(forgefiles)
        
    if forgepreversion:
        
        forgeversion = forgepreversion[0]
        forgeversionchecked = forgeversion.replace(".jar", "")
        print("La versión de Forge es:", forgeversionchecked)
        
    else:
        
        print("No se encontraron archivos en el directorio Forge.")
        
    pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{forgeversionchecked}/unix_args.txt")

    if pathtoforge: # Checa si la lista no esta vacia

        path = pathtoforge[0] # Obtiene la primera ruta de la lista

        print(path)

        # !java @user_jvm_args.txt "@{path}" "$@"

    else:

        print("No se encontro el archivo unix_args.txt.")

#Si el servidor es de tipo Vanilla o paper o mohist o catserver o fabric o purpur

else:

    #Ejecuta el archivo jar del servidor
    
    # !java $memory_allocation $server_flags -jar $jar_name nogui

# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)  # Espera 1 minuto
# Out:
# el apt cache fue actualizado correctamente
# PhilipsRuins	     eula.txt	    mods	       start.sh
# READ_ME.txt	     forge.jar	    ops.json	       user_jvm_args.txt
# banned-ips.json      forge.jar.log  run.bat	       usercache.json
# banned-players.json  libraries	    run.sh	       usernamecache.json
# colabconfig.json     localconfigs   server-icon.png    variables.txt
# config		     logs	    server.properties  whitelist.json
# defaultconfigs	     modernfix	    start.ps1	       world
# OpenJDK purgado correctamente
# OpenJDK 17 instalado correctamente
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# t=2024-03-13T18:43:46+0000 lvl=warn msg="can't bind default web address, trying alternatives" obj=web addr=127.0.0.1:4040
# La IP de tu servidor es 0.tcp.sa.ngrok.io:12671
# Estas jugando a minecraft: forge en su version: 1.19.2
# La versión de Forge es: 1.19.2-43.3.8
# /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/1.19.2-43.3.8/unix_args.txt
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [18:43:49] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 43.3.8, --fml.mcVersion, 1.19.2, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20220805.130853]
# [18:43:49] [main/INFO] [cp.mo.mo.Launcher/MODLAUNCHER]: ModLauncher 10.0.8+10.0.8+main.0ef7e830 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# [18:43:50] [main/INFO] [mixin/]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%2363!/ Service=ModLauncher Env=SERVER
# [18:43:51] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/fmlcore/1.19.2-43.3.8/fmlcore-1.19.2-43.3.8.jar is missing mods.toml file
# [18:43:51] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/javafmllanguage/1.19.2-43.3.8/javafmllanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:43:51] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/lowcodelanguage/1.19.2-43.3.8/lowcodelanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:43:51] [main/WARN] [ne.mi.fm.lo.mo.ModFileParser/LOADING]: Mod file /workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/mclanguage/1.19.2-43.3.8/mclanguage-1.19.2-43.3.8.jar is missing mods.toml file
# [18:43:51] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [18:43:51] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: terrablender. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/TerraBlender-forge-1.19.2-2.0.1.166.jar
# [18:43:51] [main/WARN] [ne.mi.ja.se.JarSelector/]: Attempted to select a dependency jar for JarJar which was passed in as source: curios. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/curios-forge-1.19.2-5.1.4.3.jar
# [18:43:51] [main/INFO] [ne.mi.fm.lo.mo.JarInJarDependencyLocator/]: Found 13 dependencies adding them to mods collection
# [18:43:55] [main/INFO] [mixin/]: Compatibility level set to JAVA_17
# [18:43:55] [main/ERROR] [mixin/]: Mixin config necronomicon.forge.mixins.json does not specify "minVersion" property
# [18:43:55] [main/ERROR] [mixin/]: Mixin config spruceui.mixins.json does not specify "minVersion" property
# [18:43:55] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [18:43:55] [main/INFO] [mixin/]: Successfully loaded Mixin Connector [ca.spottedleaf.starlight.mixin.MixinConnector]
# [18:43:55] [main/INFO] [cp.mo.mo.LaunchServiceHandler/MODLAUNCHER]: Launching target 'forgeserver' with arguments []
# [18:43:55] [main/WARN] [mixin/]: Reference map 'insanelib.refmap.json' for insanelib.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:55] [main/INFO] [ModernFix/]: Loaded configuration file for ModernFix 5.10.0+mc1.19.2: 76 options available, 0 override(s) found
# [18:43:55] [main/INFO] [ModernFix/]: Applying Nashorn fix
# [18:43:55] [main/INFO] [ModernFix/]: Applied Forge config corruption patch
# [18:43:56] [main/WARN] [mixin/]: Reference map 'lmft-forge-refmap.json' for lmft.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/WARN] [mixin/]: Reference map 'mysticaloaktree-common-refmap.json' for mysticaloaktree-common.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/WARN] [mixin/]: Reference map 'mysticaloaktree-forge-refmap.json' for mysticaloaktree.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/WARN] [mixin/]: Reference map 'nitrogen_internals.refmap.json' for nitrogen_internals.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/WARN] [mixin/]: Reference map 'EpheroLib-refmap.json' for epherolib.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/WARN] [mixin/]: Reference map 'fastpaintings-forge-refmap.json' for fastpaintings-forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [18:43:56] [main/INFO] [co.cu.Cupboard/]: Loaded config for: recipeessentials.json
# [18:43:56] [main/INFO] [co.cu.Cupboard/]: Loaded config for: structureessentials.json
# [18:43:56] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry for invalid dist DEDICATED_SERVER
# [18:43:56] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/worldselection/WorldSelectionList$WorldListEntry for invalid dist DEDICATED_SERVER)
# [18:43:56] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.worldselection.WorldSelectionList$WorldListEntry was not found modernfix-common.mixins.json:bugfix.world_screen_skipped.WorldSelectionListMixin
# [18:43:57] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/worldselection/CreateWorldScreen for invalid dist DEDICATED_SERVER
# [18:43:57] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/worldselection/CreateWorldScreen (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/worldselection/CreateWorldScreen for invalid dist DEDICATED_SERVER)
# [18:43:57] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.worldselection.CreateWorldScreen was not found modernfix-forge.mixins.json:bugfix.extra_experimental_screen.CreateWorldScreenMixin
# [18:43:57] [main/WARN] [mixin/]: Error loading class: vectorwing/farmersdelight/common/block/TomatoVineBlock (java.lang.ClassNotFoundException: vectorwing.farmersdelight.common.block.TomatoVineBlock)
# [18:43:57] [main/WARN] [mixin/]: @Mixin target vectorwing.farmersdelight.common.block.TomatoVineBlock was not found supplementaries.mixins.json:CompatFarmersDelightMixin
# [18:43:57] [main/WARN] [mixin/]: Error loading class: net/mcreator/midnightmadness/procedures/WelcomingMSGProcedure (java.lang.ClassNotFoundException: net.mcreator.midnightmadness.procedures.WelcomingMSGProcedure)
# [18:43:57] [main/WARN] [mixin/]: @Mixin target net.mcreator.midnightmadness.procedures.WelcomingMSGProcedure was not found teraphobia.mixins.json:integrations.midnight_madness.RemoveWelcomeMessageMixin
# [18:43:57] [main/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class net/minecraft/client/gui/screens/multiplayer/ServerSelectionList for invalid dist DEDICATED_SERVER
# [18:43:57] [main/WARN] [mixin/]: Error loading class: net/minecraft/client/gui/screens/multiplayer/ServerSelectionList (java.lang.RuntimeException: Attempted to load class net/minecraft/client/gui/screens/multiplayer/ServerSelectionList for invalid dist DEDICATED_SERVER)
# [18:43:57] [main/WARN] [mixin/]: @Mixin target net.minecraft.client.gui.screens.multiplayer.ServerSelectionList was not found serverbrowser.mixins.json:ServerSelectionMixin
# [18:43:57] [main/WARN] [mixin/]: Error loading class: noobanidus/mods/lootr/config/ConfigManager (java.lang.ClassNotFoundException: noobanidus.mods.lootr.config.ConfigManager)
# [18:43:58] [main/WARN] [ne.to.pa.mi.MixinConfigPlugin/]: For can't fit X into 3 error fix. Delete Krypton.
# [18:43:58] [main/WARN] [ne.to.pa.mi.MixinConfigPlugin/]: For can't fit X into 3 error fix. Delete Krypton.
# [18:43:58] [main/WARN] [mixin/]: Error loading class: com/mojang/blaze3d/audio/Channel (java.lang.ClassNotFoundException: com.mojang.blaze3d.audio.Channel)
# [18:43:58] [main/WARN] [mixin/]: @Mixin target com.mojang.blaze3d.audio.Channel was not found assets/sound_physics_remastered/sound_physics_remastered.mixins.json:ChannelAccessor
# [18:43:58] [main/INFO] [memoryleakfix/]: [MemoryLeakFix] Will be applying 2 memory leak fixes!
# [18:43:58] [main/INFO] [memoryleakfix/]: [MemoryLeakFix] Currently enabled memory leak fixes: [entityMemoriesLeak, biomeTemperatureLeak]
# [18:43:58] [main/INFO] [MixinExtras|Service/]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.2.0-rc.5).
# [18:43:58] [main/WARN] [MixinExtras|Service/]: Found problematic active MixinExtras instance at ca.fxco.memoryleakfix.mixinextras (version 0.2.0-beta.8)
# [18:43:58] [main/WARN] [MixinExtras|Service/]: Versions from 0.2.0-beta.1 to 0.2.0-beta.9 have limited support and it is strongly recommended to update.
# [18:43:59] [main/INFO] [minecraft/Bootstrap]: ModernFix reached bootstrap stage (12.00 s after launch)
# [18:43:59] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into getOpacityIfCached from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [18:43:59] [main/INFO] [ModernFix/]: Injecting BlockStateBase cache population hook into isConditionallyFullOpaque from ca.spottedleaf.starlight.mixin.common.blockstate.BlockStateBaseMixin
# [18:43:59] [main/WARN] [mixin/]: @Inject(@At("INVOKE")) Shift.BY=2 on sanitydim.mixins.json:MixinEntity::handler$zlj000$move exceeds the maximum allowed value: 0. Increase the value of maxShiftBy to suppress this warning.
# [18:44:01] [main/INFO] [minecraft/Bootstrap]: Vanilla bootstrap took 2479 milliseconds
# [18:44:01] [main/WARN] [mixin/]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientBoundCustomPayloadPacketLMixin->@ModifyConstant::modifyLimit(I)I with priority 1, already redirected by packetfixer.mixins.json:ClientboundCustomPayloadPacketMixin->@ModifyConstant::newSize(I)I with priority 9999
# [18:44:01] [main/WARN] [mixin/]: @ModifyConstant conflict. Skipping connectivity.mixins.json:ClientBoundCustomPayloadPacketLMixin->@ModifyConstant::modifyLimit(I)I with priority 1, already redirected by packetfixer.mixins.json:ClientboundCustomPayloadPacketMixin->@ModifyConstant::newSize(I)I with priority 9999
# [18:44:04] [main/WARN] [mixin/]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [18:44:06] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.TagsFeature
# [18:44:06] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.FixFeature
# [18:44:06] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.insanelib.module.base.feature.AEC3DFeature
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option debugConsole, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option debugConsoleOmniscient, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option debugConsoleSuperDetailed, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option client_renderBlood, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option client_debugSensesVisual, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option soundAlerts, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/WARN] [ne.mi.co.ForgeConfigSpec/CORE]: Detected a comment that is all whitespace for config option soundInvestigates, which causes obscure bugs in Forge's config system and will cause a crash in the future. Please report this to the mod author.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [Bookshelf/]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# [18:44:06] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Successfully initialized!
# [18:44:06] [modloading-worker-0/INFO] [de.ke.ko.Konkrete/]: [KONKRETE] Server-side libs ready to use!
# [18:44:07] [modloading-worker-0/INFO] [io.wi.lm.LMFTCommon/]: [LMFT]: Loaded Config File!
# [18:44:07] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod leavesbegone
# [18:44:07] [modloading-worker-0/INFO] [cr.sa.SanityMod/]: Applying dimension config example.toml
# [18:44:07] [modloading-worker-0/INFO] [de.wu.bc.BCC/]: Better Compatibility Checker loading
# [18:44:07] [modloading-worker-0/INFO] [co.cu.Cupboard/]: Loaded config for: memorysettings.json
# [18:44:07] [modloading-worker-0/INFO] [Collective/]: Loading Collective version 7.13.
# [18:44:07] [modloading-worker-0/INFO] [co.ae.cu.Cumulus/]: Disabling Cumulus as it is on server.
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id architectury:sync_ids
# [18:44:07] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod netherchested
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/76a3075595713f9ead985fe1b5bc670f
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/4f7690f0914131bfb637c4b9db1a0d1c
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/a6daf1a1e95931bc8f3abcbda1a2ae9d
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/840fe05af8cd3b4aa95281c6cc221938
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/17c566f85bb03fb69f8615e26b6784b4
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/b80b4c698dec3f6f87b9726830b1ace8
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/544a29a5d5183866803b64316e1294b1
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/c36dcfa0b7ab3b8bb8b35a54b6d07097
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/f802f5d752b638be9b7c637a8a4c19d6
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/99444a2917f03fe5a9692032bd12bf33
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/69fd935ac1a93efaa9557e3279ab6dff
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/ffb125f7948b3624985f99a74b44b6b6
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/65e1afdf666c30bca0c2c459fb9cb3be
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/b097a3dc46b7325b9cd24ba38d0447b4
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.zombie.feature.PearlerZombie
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/26ac8e7ddec3356bb6764befd257dc32
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/14126b0bf54233409f83ae93b77196f7
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/0011717adeda362481b4fc4e9dc0eeb9
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.zombie.feature.FisherZombie
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/a55bce397a523be2895599ebf32bb8f3
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id immersivemc:immersive_mc/8fc988cfeded3ca4af3631137cc4d74f
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.zombie.feature.DiggerZombie
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.feature.WitchPotionThrowing
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.feature.WitchFleeTarget
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.feature.ThirstyWitches
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.witch.feature.DarkArtWitch
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.villager.feature.VillagerAttacking
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.spider.feature.ThrowingWeb
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.spider.feature.Misc
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.skeleton.feature.SkeletonShoot
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.skeleton.feature.SkeletonFleeTarget
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.ghast.feature.GhastShoot
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.enderman.feature.ItemDisruption
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.enderman.feature.GetOverHere
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.drowned.feature.DrownedSwimming
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.creeper.feature.CreeperSwell
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.blaze.feature.BlazeAttack
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.Targeting
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.Shielding
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.Movement
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.Base
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.AvoidExplosions
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.Attacking
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.base.feature.AntiCheese
# [18:44:07] [modloading-worker-0/INFO] [in.in.InsaneLib/]: Found (COMMON) InsaneLib Feature class insane96mcp.enhancedai.modules.animal.feature.AnimalAttacking
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftblibrary:edit_nbt_response
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:open_gui
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:update_settings
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:send_message
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:create_party
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbteams:player_gui_operation
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/14e7fa1454283aec8ae811ef844ada28
# [18:44:07] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id itemfilters:main/8f6a899247753217b9d86ab427a2b279
# [18:44:07] [modloading-worker-0/INFO] [Kiwi/Init]: Processing 4 KiwiModule annotations
# [18:44:07] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod visualworkbench
# [18:44:08] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@2e1eb85f on thread Thread[#38,modloading-worker-0,5,main]
# [18:44:08] [modloading-worker-0/ERROR] [ne.mi.ev.EventSubclassTransformer/EVENTBUS]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:92) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:44) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.3.jar%2351!/:?] {}
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.3.jar%2351!/:6.0.3+6.0.3+master.039e4ea9] {}
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.8.jar%2354!/:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:113) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:219) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:229) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:219) ~[securejarhandler-2.1.4.jar:?] {}
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:135) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?] {}
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?] {}
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?] {}
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?] {}
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?] {}
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?] {}
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?] {re:mixin}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?] {}
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?] {}
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23370!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:26) ~[obscure_api-15.jar%23370!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:42) ~[obscure_api-15.jar%23370!/:15] {re:classloading}
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:68) ~[obscure_api-15.jar%23370!/:15] {re:classloading}
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?] {}
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?] {}
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:70) ~[javafmllanguage-1.19.2-43.3.8.jar%23443!/:?] {}
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$4(ModContainer.java:122) ~[fmlcore-1.19.2-43.3.8.jar%23442!/:?] {re:mixin}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?] {}
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?] {}
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?] {}
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?] {re:mixin,re:computing_frames}
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?] {re:mixin,re:computing_frames}
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?] {re:mixin}
# [18:44:08] [modloading-worker-0/ERROR] [ne.mi.fm.lo.RuntimeDistCleaner/DISTXFORM]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [18:44:08] [modloading-worker-0/INFO] [FTB XMod Compat/]: Chose [Entity Tags] as the active game stages implementation
# [18:44:08] [modloading-worker-0/INFO] [FTB XMod Compat/]: Chose [FALLBACK] as the active permissions implementation
# [18:44:08] [modloading-worker-0/INFO] [FTB XMod Compat/]: [FTB Quests] recipe helper provider is [JEI]
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:submit_task
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_reward
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:get_emergency_items
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_all_rewards
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:claim_choice_reward
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id gardens_of_the_dead:networking_channel/bc2f24ca5d503301bb3abf7b928d614e
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_pinned
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_chapter_pinned
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:toggle_editing_mode
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:force_save
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:set_custom_image
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:task_screen_config_resp
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_progress
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_object
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:create_task_at
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:delete_object
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:edit_object
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_quest
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:change_chapter_group
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:move_chapter_group
# [18:44:08] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:copy_quest
# [18:44:09] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:copy_chapter_image
# [18:44:09] [modloading-worker-0/INFO] [de.ar.ne.fo.NetworkManagerImpl/]: Registering C2S receiver with id ftbquests:sync_structures_request
# [18:44:09] [modloading-worker-0/INFO] [Puzzles Lib/]: Constructing common components for mod mindfuldarkness
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: loading json file and contents for paintings.
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: **Paintings++ no longer copies the base file outside if the mod. **
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_blue , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_rainbow , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_red , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting abstract_sunset , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting arachnophobe , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting barn_owl , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting big_z , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting blue_bird , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting bluesclues , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting borgia , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cane , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_black , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_gray , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat_orange , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting cat , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting colorful_squares , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting crest , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting danger_zone , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting decorative_gun , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_down , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_up , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_left , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting exit_right , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_bat , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_chicken , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_cow , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_creeper , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_dog , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_enderman , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_pig , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_pigman , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_silverfish , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_skeleton , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_squid , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting face_zombie , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting fishes , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting flowers , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting fruits , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting ghost , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting glowlamp , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting glowstone_hourglass , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting iluvmc , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting link , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting mine_prosperity , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting no_trespassing_for_mobs , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting ocelot , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting penguin , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pig_on_a_cliff , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_blue , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_red , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting pkmn_green , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting plains_hut , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting portrait_2 , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting portrait , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting prison , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting prosperity , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting rest , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting skeleton , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting sky , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting skyblock , 32 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting snake , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting snow_landscape , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting subaraki , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting synth_city , 16 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_a , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_b , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting tapistry_purple , 16 x 32
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting torched , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting waterfall , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting whale , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting wheat_field , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [paintings/]: Loaded json painting wolf_in_wheat , 32 x 16
# [18:44:09] [modloading-worker-0/INFO] [ne.mi.co.ForgeMod/FORGEMOD]: Forge mod loading, version 43.3.8, for MC 1.19.2 with MCP 20220805.130853
# [18:44:09] [modloading-worker-0/INFO] [ne.mi.co.MinecraftForge/FORGE]: MinecraftForge v43.3.8 Initialized
# [18:44:09] [modloading-worker-0/INFO] [xy.ap.fo.co.Mo.CommonalityMod/]: Running Minecraft '1.19.2', & Forge '43.3.8' on Java '21.0.2, Microsoft'
# [18:44:09] [modloading-worker-0/INFO] [TrustedSourceList/]: Loading BlackListed sources from remote... (https://api.stopmodreposts.org/minecraft/sites.txt)
# [18:44:09] [modloading-worker-0/INFO] [TrustedSourceList/]: Loaded 564 BlackListed sources from remote
# [18:44:09] [modloading-worker-0/INFO] [TrustManager/]: Loading mod 'commonality' TrustWorthiness...
# [18:44:09] [modloading-worker-0/FATAL] [TrustManager/]: Could not determine mod trust worthiness, Assuming Jar was downloaded from trusted source!
# [18:44:09] [modloading-worker-0/INFO] [TrustManager/]: Loaded mod 'commonality' TrustWorthiness: UNKNOWN
# [18:44:09] [modloading-worker-0/INFO] [betterstats/]: Initializing 'Better Statistics Screen' as 'BetterStatsServer'.
# [18:44:09] [modloading-worker-0/INFO] [tcdcommons/]: Initializing 'TCDCommons API' as 'TCDCommonsServer'.
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.VariantSelectorModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.NarratorReadoutModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.ClimateControlRemoverModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.EnchantmentsBegoneModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.GameNerfsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.SpawnerReplacerModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.AdjustableChatModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.VillagerRerollingReworkModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.OverlayShaderModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.experimental.module.EnchantmentPredicatesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantLaddersModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantBookshelvesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.BambooBackportModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CompressedBlocksModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MorePottedPlantsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.DuskboundBlocksModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.WoodenPostsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ThatchModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreStoneVariantsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShearVinesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.NetherBrickFenceGateModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GoldBarsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.RopeModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.CelebratoryLampsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SoulSandstoneModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantChestsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.LeafCarpetModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.FramedGlassModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalPlanksModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VariantFurnacesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.HedgesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.HollowLogsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MidoriModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.RainbowLampsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.VerticalSlabsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.ShinglesModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.SturdyStoneModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.StoolsModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.RawMetalBricksModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.MoreMudBlocksModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.GrateModule
# [18:44:09] [modloading-worker-0/INFO] [quark/]: Found Quark module class vazkii.quark.content.building.module.JapanesePaletteModule
# ...
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_medium with loottable: minecraft:chests/stronghold_crossing
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hanging_sign_acacia use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_easy with loottable: minecraft:chests/simple_dungeon
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_nether with loottable: minecraft:chests/nether_bridge
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_pink_bioshroom use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_hard with loottable: minecraft:chests/end_city_treasure
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_water with loottable: minecraft:chests/underwater_ruin_big
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_cypress use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_palm use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_cobalt use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/gardens_of_the_dead/hanging_sign_soulblight use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:dungeonloot_no_overflow with loottable: minecraft:chests/simple_dungeon
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_blue_bioshroom use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_mauve use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_joshua use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hanging_sign_birch use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hexerei/hanging_sign_witch_hazel use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_kapok use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_maple use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/born_in_chaos_v1/hanging_sign_scorched use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_dead use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_eucalyptus use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/quark/hanging_sign_blossom use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hanging_sign_jungle use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hanging_sign_warped use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/endlessbiomes/hanging_sign_twisted use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_baobab use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/quark/hanging_sign_bamboo use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_willow use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_yellow_bioshroom use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/quark/hanging_sign_ancient use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_pine use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Parsing loot modifiers for:lootintegrations:villageloot_house with loottable: minecraft:chests/village/village_plains_house
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/hanging_sign_mangrove use this folder name:lootintegrations
# [18:44:26] [main/WARN] [co.lo.LootintegrationsMod/]: Ignoring loot modifiers for:supplementaries:tables/blocks/regions_unexplored/hanging_sign_larch use this folder name:lootintegrations
# [18:44:26] [main/INFO] [co.te.bl.co.Blueprint/]: Structure Repaletter Manager has loaded 0 repaletters
# [18:44:26] [main/INFO] [co.te.bl.co.Blueprint/]: Modded Biome Slice Manager has loaded 1 slices
# [18:44:26] [main/INFO] [co.te.bl.co.Blueprint/]: Chunk Generator Modification Manager has loaded 0 modifier groups
# [18:44:26] [main/WARN] [ne.mi.co.lo.LootModifierManager/]: Could not decode GlobalLootModifier with json id bygonenether:soul_stone_from_block - error: Unknown registry key in ResourceKey[minecraft:root / forge:global_loot_modifier_serializers]: bygonenether:replace_item
# [18:44:26] [main/WARN] [ne.mi.co.lo.LootModifierManager/]: Could not decode GlobalLootModifier with json id bygonenether:soul_stone_in_catacombs - error: Unknown registry key in ResourceKey[minecraft:root / forge:global_loot_modifier_serializers]: bygonenether:replace_item
# [18:44:26] [main/INFO] [supplementaries/]: Loaded  8 flute songs
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:husbandry/wax_on with 2 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:husbandry/make_a_sign_glow with 1 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:husbandry/balanced_diet with 1 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:husbandry/plant_seed with 1 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:nether/all_effects with 1 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:husbandry/wax_off with 2 patches
# [18:44:26] [main/INFO] [quark/]: Modified advancement minecraft:adventure/adventuring_time with 1 patches
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_cod_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.cod
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_salmon_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.salmon
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_pufferfish_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.pufferfish
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_tropical_fish_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.tropical_fish
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_axolotl_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.axolotl
# [18:44:26] [main/WARN] [supplementaries/]: Error white registering dispenser behavior for item skyroot_tadpole_bucket: java.lang.IllegalArgumentException: value already present: entity.minecraft.tadpole
# [18:44:26] [main/INFO] [supplementaries/]: Finished additional setup in 63 ms
# [18:44:26] [main/WARN] [minecraft/DedicatedServerProperties]: Failed to parse level-type default, defaulting to minecraft:normal
# [18:44:26] [Server thread/INFO] [minecraft/DedicatedServer]: Starting minecraft server version 1.19.2
# [18:44:26] [Server thread/INFO] [minecraft/DedicatedServer]: Loading properties
# [18:44:26] [Server thread/INFO] [minecraft/DedicatedServer]: Default game type: SURVIVAL
# [18:44:26] [Server thread/INFO] [minecraft/MinecraftServer]: Generating keypair
# [18:44:26] [Server thread/INFO] [minecraft/DedicatedServer]: Starting Minecraft server on *:25565
# [18:44:26] [Server thread/INFO] [minecraft/ServerConnectionListener]: Using epoll channel type
# [18:44:26] [Server thread/WARN] [minecraft/DedicatedServer]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [18:44:26] [Server thread/WARN] [minecraft/DedicatedServer]: The server will make no attempt to authenticate usernames. Beware.
# [18:44:26] [Server thread/WARN] [minecraft/DedicatedServer]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [18:44:26] [Server thread/WARN] [minecraft/DedicatedServer]: To change this, set "online-mode" to "true" in the server.properties file.
# [18:44:27] [Server thread/INFO] [Puzzles Lib/]: Loading server config for leavesbegone
# [18:44:27] [Server thread/INFO] [Puzzles Lib/]: Loading server config for netherchested
# [18:44:27] [Server thread/INFO] [FTB Teams/]: loaded team data: 2 known players, 2 teams total
# [18:44:27] [Server thread/INFO] [spark/]: Starting background profiler...
# [18:44:27] [Server thread/INFO] [configured/]: Loading server configs...
# [18:44:27] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem minecraft:the_nether
# [18:44:28] [Server thread/INFO] [terrablender/]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [18:44:28] [Server thread/INFO] [minecraft/DedicatedServer]: Preparing level "world"
# [18:44:28] [Server thread/INFO] [minecraft/MinecraftServer]: Preparing start region for dimension minecraft:overworld
# [18:44:30] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:44:30] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:44:30] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:44:30] [Worker-Main-3/WARN] [mixin/]: @Redirect conflict. Skipping redirector.mixins.json:net.minecraft.world.level.block.state.CacheMixin->@Redirect::redirectSupportTypes()[Lnet/minecraft/world/level/block/SupportType; with priority 10, already redirected by modernfix-common.mixins.json:perf.cache_blockstate_cache_arrays.AbstractBlockStateCacheMixin->@Redirect::getVoxelShapeValues()[Lnet/minecraft/world/level/block/SupportType; with priority 1000
# [18:44:30] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 0%
# [18:44:30] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: betterchunkloading.json
# [18:44:30] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 22%
# [18:44:31] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Preparing spawn area: 55%
# [18:44:31] [Server thread/INFO] [minecraft/LoggerChunkProgressListener]: Time elapsed: 2859 ms
# [18:44:31] [Server thread/INFO] [minecraft/DedicatedServer]: Done (4.662s)! For help, type "help"
# [18:44:31] [Server thread/INFO] [ne.mi.se.pe.PermissionAPI/]: Successfully initialized permission handler forge:default_handler
# > Performing a full config mod force sync
# Coro ConfigMod updating runtime values for file: zombieawareness/ClientConfig
# Coro ConfigMod updating runtime values for file: zombieawareness/General
# Coro ConfigMod updating runtime values for file: zombieawareness/PlayerRulesAndLists
# Coro ConfigMod updating runtime values for file: zombieawareness/Features
# [18:44:31] [Server thread/INFO] [FTB Quests/]: Loading quests from /workspaces/codespaces-jupyter/Minecraft-server/config/ftbquests/quests
# [18:44:31] [Server thread/INFO] [FTB Quests/]: Loaded 3 chapter groups, 9 chapters, 143 quests, 0 reward tables
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: connectivity.json
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: lootintegrations.json
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: cupboard.json
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: smoothchunk.json
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: betterfpsdist.json
# [18:44:31] [Server thread/INFO] [co.cu.Cupboard/]: Loaded config for: chunksending.json
# [18:44:31] [Server thread/WARN] [voicechat/]: [voicechat] Running in offline mode - Voice chat encryption is not secure!
# [18:44:31] [VoiceChatServerThread/INFO] [voicechat/]: [voicechat] Voice chat server started at port 24454
# [18:44:31] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 ash_scythe, missing knowledge for {1 stone_sword=1.0}
# [18:44:31] [Server thread/INFO] [immersiveengineering/]: Couldn't fully analyze 1 radiator, missing knowledge for {1 water_bucket=0.25}
# [18:44:31] [Server thread/INFO] [immersiveengineering/]: Finished recipe profiler for Arc Recycling, took 80 milliseconds
# [18:44:31] [Server thread/WARN] [ModernFix/]: Dedicated server took 44.695 seconds to load
# >
# >[18:46:26] [Server console handler/ERROR] [minecraft/DedicatedServer]: Caught previously unhandled exception :
# java.lang.NoClassDefFoundError: org/jline/terminal/Terminal$MouseTracking
# 	at org.jline.reader.impl.LineReaderImpl.doCleanup(LineReaderImpl.java:2432) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.cleanup(LineReaderImpl.java:2419) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:648) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at org.jline.reader.impl.LineReaderImpl.readLine(LineReaderImpl.java:418) ~[jline-reader-3.12.1.jar%2361!/:?] {}
# 	at net.minecraftforge.server.console.TerminalHandler.handleCommands(TerminalHandler.java:46) ~[forge-1.19.2-43.3.8-universal.jar%23446!/:?] {re:classloading}
# 	at net.minecraft.server.dedicated.DedicatedServer$1.run(DedicatedServer.java:85) ~[server-1.19.2-20220805.130853-srg.jar%23441!/:?] {re:classloading}
# Caused by: java.lang.ClassNotFoundException: org.jline.terminal.Terminal$MouseTracking
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:141) ~[securejarhandler-2.1.4.jar:?] {}
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?] {}
# 	... 6 more
